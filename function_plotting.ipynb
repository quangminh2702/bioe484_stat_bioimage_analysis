# %% [markdown]
# ## Plotting of Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# %%
# Define the time-domain signal
def x(t):
    signal_value = []
    for time_value in t:
        if -1/2<=time_value<=1/2:
            signal_value.append(1)
        else:
            signal_value.append(0)
    return np.array(signal_value)

# Generate time values
t = np.linspace(-5, 5, 1000, endpoint=False)

# Calculate the signal values
x_t = x(t)

# Plot the time-domain signal
plt.subplot(2, 1, 1)
plt.plot(t, x_t)
plt.title('Time-Domain Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
# Calculate the Fourier Transform
frequencies = fftfreq(len(t), t[1] - t[0])
X_f = fft(x_t)/len(t)  #normalized wrt the length of data

# Plot the time-domain signal
plt.subplot(2, 1, 1)
plt.plot(t, x_t)
plt.title('Time-Domain Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')

# Plot the magnitude of the Fourier Transform
plt.subplot(2, 1, 2)
plt.plot(frequencies, np.abs(X_f))
plt.title('Fourier Transform')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')
plt.xlim(-40,40)

plt.tight_layout()
plt.show()

# %%
# Calculate the magnitude
magnitude = np.abs(X_f)
# Remove elements below the threshold (0.1)
threshold = 0.01
a = magnitude[magnitude > threshold]

print(a)
# Out:
# [0.601      0.30242068 0.09435671 0.06155509 0.07598771 0.05014012
#  0.02753297 0.02257329 0.0339368  0.027201   0.01639312 0.01357512
#  0.02191869 0.01859571 0.01180431 0.01622328 0.01408581 0.01289888
#  0.01130857 0.01071911 0.01071911 0.01130857 0.01289888 0.01408581
#  0.01622328 0.01180431 0.01859571 0.02191869 0.01357512 0.01639312
#  0.027201   0.0339368  0.02257329 0.02753297 0.05014012 0.07598771
#  0.06155509 0.09435671 0.30242068]

# %%
# Define the time-domain signal
def x(t):
    signal_value = []
    for time_value in t:
        if time_value==2:
            signal_value.append(1)
        else:
            signal_value.append(0)
    return np.array(signal_value)

# Generate time values
t = np.linspace(-5, 5, 1000, endpoint=False)

# Calculate the signal values
x_t = x(t)

# Plot the time-domain signal
plt.subplot(2, 1, 1)
plt.plot(t, x_t)
plt.title('Time-Domain Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
# Calculate the Fourier Transform
frequencies = fftfreq(len(t), t[1] - t[0])
X_f = fft(x_t)  #normalized wrt the length of data

# Plot the time-domain signal
plt.subplot(2, 1, 1)
plt.plot(t, x_t)
plt.title('Time-Domain Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')

# Plot the magnitude of the Fourier Transform
plt.subplot(2, 1, 2)
plt.plot(frequencies, np.abs(X_f))
plt.title('Fourier Transform')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')
plt.xlim(-40,40)

plt.tight_layout()
plt.show()
